# %%
# !pip install pyramid
# Out:
# ...
#      |████████████████████████████████| 326 kB 3.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 114 kB 11.5 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import sys; print("Python Version----", sys.version)
import numpy; print("Numpy Version----", numpy.__version__)
import scipy; print("Sci-Py Version----", scipy.__version__)
import sklearn; print("Scikit-Learn Version----", sklearn.__version__)
import pandas; print("Pandas Version----", pandas.__version__)
import statsmodels; print("Statsmodels Version----", statsmodels.__version__)
import pyramid; print("Pyramid Version----", '1.10.5') # no such atribute __version__ 
import pip; print("Pip Version----", pip.__version__)
# Out:
# Python Version---- 3.7.6 (default, Jan  8 2020, 13:42:34)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Numpy Version---- 1.18.1
# Sci-Py Version---- 1.4.1
# Scikit-Learn Version---- 0.22.1
# Pandas Version---- 1.1.4
# Statsmodels Version---- 0.12.1
# Pyramid Version---- 1.10.5
# Pip Version---- 20.3.1

# %%
# !pip install pyramid-arima
# Out:
# ...
#      |████████████████████████████████| 515 kB 5.0 MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/ps/lfq5vmk5793cw8f0kjkpnc3m0000gn/T/pip-install-f2bn5gzk/pyramid-arima_cfaf3c37401f47a7824a5cc021868a1a/setup.py'"'"'; __file__='"'"'/private/var/folders/ps/lfq5vmk5793cw8f0kjkpnc3m0000gn/T/pip-install-f2bn5gzk/pyramid-arima_cfaf3c37401f47a7824a5cc021868a1a/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/ps/lfq5vmk5793cw8f0kjkpnc3m0000gn/T/pip-wheel-m6zmh8q5
#        cwd: /private/var/folders/ps/lfq5vmk5793cw8f0kjkpnc3m0000gn/T/pip-install-f2bn5gzk/pyramid-arima_cfaf3c37401f47a7824a5cc021868a1a/
#   Complete output (250 lines):
#   Partial import of pyramid during the build process.
# ...

# %%
# !pip install pmdarima
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 2.6 MB/s eta 0:00:01
# ...
#   Created wheel for pmdarima: filename=pmdarima-1.8.0-cp37-cp37m-macosx_10_14_x86_64.whl size=615125 sha256=5a71b02eae1f7dc5470dd195c43bf89850b405b84dcabcb13fd42ffc7782a87c
#   Stored in directory: /Users/gilmer/Library/Caches/pip/wheels/6b/ce/a2/ab07be3657199801d1f7c4d28cf7b6c7d4868927e8d4611e99
# Successfully built pmdarima
# ...
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import warnings
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
# %matplotlib inline
from matplotlib.pylab import rcParams
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
import pyramid as pm    # can't have this if i want auto_arima from pyramid-arima
from sklearn import metrics
from pmdarima.arima import auto_arima  # from stackoverflow, i guess the new way to access auto_arima
warnings.filterwarnings('ignore')

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
flight_data = sns.load_dataset('flights')
flight_data.head()
flight_data.tail()
flight_data.shape
flight_data.describe()
flight_data.info()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121
#      year      month  passengers
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
# (144, 3)
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
# ...

# %%
flight_data_pivot = flight_data.pivot('month', 'year', 'passengers')
flight_data_pivot
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
plt.figure(figsize = (15, 5))
sns.heatmap(flight_data_pivot, annot = True, fmt = 'd', cmap = 'YlGnBu')

# %%
month = pd.date_range('19490131', periods = 144, freq = 'M')
month
# Out:
# DatetimeIndex(['1949-01-31', '1949-02-28', '1949-03-31', '1949-04-30',
#                '1949-05-31', '1949-06-30', '1949-07-31', '1949-08-31',
#                '1949-09-30', '1949-10-31',
#                ...
#                '1960-03-31', '1960-04-30', '1960-05-31', '1960-06-30',
#                '1960-07-31', '1960-08-31', '1960-09-30', '1960-10-31',
#                '1960-11-30', '1960-12-31'],
#               dtype='datetime64[ns]', length=144, freq='M')

# %%
flight_data['datestamp'] = month
flight_data.head()
# Out:
#    year     month  passengers  datestamp
# 0  1949   January         112 1949-01-31
# 1  1949  February         118 1949-02-28
# 2  1949     March         132 1949-03-31
# 3  1949     April         129 1949-04-30
# 4  1949       May         121 1949-05-31

# %%
data = flight_data.loc[:, ('datestamp', 'passengers')]
data.head()
data.describe()
# Out:
#    datestamp  passengers
# 0 1949-01-31         112
# 1 1949-02-28         118
# 2 1949-03-31         132
# 3 1949-04-30         129
# 4 1949-05-31         121
#        passengers
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000

# %%
data.set_index('datestamp', inplace = True)
data.head()
# Out:
#             passengers
# datestamp
# 1949-01-31         112
# 1949-02-28         118
# 1949-03-31         132
# 1949-04-30         129
# 1949-05-31         121

# %%
plt.figure(figsize = (15, 10))
plt.plot(data)
plt.xlabel('Time')
plt.ylabel('Passengers in 1000')
plt.title('# of Passengers over Time')
plt.show;

# %%
decomposition = seasonal_decompose(data, model = 'multiplicative')  # could also use Additive but looks like diff. results

# %%
# plot trend of the series
plt.figure(figsize = (20, 10))
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(221)
plt.plot(data, color = '#00b8ff', label = 'Original')
plt.legend(loc = 'best')
plt.subplot(222)
plt.plot(trend, 'b', label = 'Trend')
plt.legend(loc = 'best')

plt.subplot(223)
plt.plot(seasonal, color = '#ff00ff', label = 'Seasonality')
plt.legend(loc = 'best')
plt.subplot(224)
plt.plot(residual, 'y', label = 'Residuals')
plt.legend(loc = 'best')
plt.tight_layout()
plt.show();

# %%
from pyramid.arima.stationarity import ADFTest
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-ae8128b08f6b> in <module>
# ----> 1 from pyramid.arima.stationarity import ADFTest
#
# ModuleNotFoundError: No module named 'pyramid.arima'

# %%
from pmdarima.arima.stationarity import ADFTest
adf_test = ADFTest(alpha = 0.05)   #
adf_test.is_stationary(data)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: is_stationary is deprecated and will be removed in a future release of pmdarima. Use should_diff instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (0.01, False)

# %%
# In article he gets (0.99, False), I'm guessing the package has changed and this has the same meaning

# %%
train, test = data[:100], data[100:]
train.shape
test.shape
# Out:
# (100, 1)
# (44, 1)

# %%
plt.plot(train)
plt.plot(test)
plt.show();

# %%
# p,d,q represent non-seasonal components. P,D,Q represent seasonal componentes
Arima_model = auto_arima(train, start_p = 1, start_q = 1, max_p = 8, max_q = 8, start_P = 0, start_Q = 0, max_P = 8, \
                        max_Q = 8, m = 12, seasonal = True, trace = True, d = 1, D = 1, error_action = 'warn', \
                        suppress_warnings = True, stepwise = True, random_state = 20, n_fits = 30)
Arima_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=647.341, Time=0.20 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=650.796, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=644.203, Time=0.12 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=644.733, Time=0.15 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=645.995, Time=0.04 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=646.172, Time=0.31 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=646.187, Time=0.20 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=644.600, Time=0.16 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=1.90 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=647.442, Time=0.07 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=646.085, Time=0.15 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=645.647, Time=0.17 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=644.346, Time=0.12 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=647.580, Time=0.26 sec
# ...

# %%
prediction = pd.DataFrame(Arima_model.predict(n_periods = 44), index = test.index)
prediction.columns = ['Predicted_Passengers']

# %%
prediction
# Out:
#             Predicted_Passengers
# datestamp
# 1957-05-31            353.433649
# 1957-06-30            406.781321
# 1957-07-31            447.984392
# 1957-08-31            438.051605
# 1957-09-30            391.246543
# 1957-10-31            344.585092
# 1957-11-30            309.159969
# 1957-12-31            345.436074
# 1958-01-31            353.798005
# 1958-02-28            341.286867
# 1958-03-31            393.096441
# 1958-04-30            385.947221
# 1958-05-31            391.288635
# 1958-06-30            445.200445
# 1958-07-31            485.934933
# 1958-08-31            476.413240
# 1958-09-30            428.928631
# 1958-10-31            381.769781
# 1958-11-30            346.435080
# 1958-12-31            382.439764
# 1959-01-31            390.937409
# 1959-02-28            378.109597
# 1959-03-31            430.597759
# 1959-04-30            423.267583
# 1959-05-31            428.628615
# 1959-06-30            482.420435
# 1959-07-31            523.254588
# ...

# %%
plt.figure(figsize = (15, 10))
plt.plot(train, label = 'Training')
plt.plot(test, label = 'Test')
plt.plot(prediction, label = 'Predicted')
plt.legend(loc = 'upper center')
plt.show();

# %%
test['Predicted_Passengers'] = prediction
test['Error'] = test['passengers'] - test['Predicted_Passengers']
test
# Out:
#             passengers  Predicted_Passengers      Error
# datestamp
# 1957-05-31         355            353.433649   1.566351
# 1957-06-30         422            406.781321  15.218679
# 1957-07-31         465            447.984392  17.015608
# 1957-08-31         467            438.051605  28.948395
# 1957-09-30         404            391.246543  12.753457
# 1957-10-31         347            344.585092   2.414908
# 1957-11-30         305            309.159969  -4.159969
# 1957-12-31         336            345.436074  -9.436074
# 1958-01-31         340            353.798005 -13.798005
# 1958-02-28         318            341.286867 -23.286867
# 1958-03-31         362            393.096441 -31.096441
# 1958-04-30         348            385.947221 -37.947221
# 1958-05-31         363            391.288635 -28.288635
# 1958-06-30         435            445.200445 -10.200445
# 1958-07-31         491            485.934933   5.065067
# 1958-08-31         505            476.413240  28.586760
# ...

# %%
metrics.mean_absolute_error(test.passengers, test.Predicted_Passengers)
# Out:
# 21.538631292811466

# %%
metrics.mean_squared_error(test.passengers, test.Predicted_Passengers)
# Out:
# 686.7476365298645

# %%
metrics.median_absolute_error(test.passengers, test.Predicted_Passengers)
# Out:
# 22.33408856852529

# %%
# My errors are better!, they must have improved the model, haha

plt.figure(figsize = (20, 10))
plt.subplot(121)
plt.plot(test.Error, color = '#ff33CC')
plt.title('Error Distribution Over Time')
plt.subplot(122)
scipy.stats.probplot(test.Error, plot = plt)
plt.show;

plt.figure(figsize = (20, 10))
pm.utils.autocorr_plot(test.Error)
plt.show();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-2539040933c9> in <module>
#      10
#      11 plt.figure(figsize = (20, 10))
# ---> 12 pm.utils.visualization.autocorr_plot(test.Error)
#      13 plt.show();
#
# AttributeError: module 'pyramid' has no attribute 'utils'

# %%
# Well I can't seem to figure out how to make the autocorr plot, he does. Pyramid seems to have changed a lot
